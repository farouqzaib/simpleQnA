# %%
import pandas as pd
import numpy as np
from  sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, VotingClassifier
import string
import codecs
from nltk.stem.wordnet import WordNetLemmatizer
lmtzr = WordNetLemmatizer()
#nltk.download()

# %% [markdown]
# <p><b>IMPORTANT: You need to download the wordnet corpus</b></p>

# %%
stopwords = ['to', 'is', 'of', 'the', 'are', 'am', 'if', 'a', 'at', 'in', 'it', 
             'an', 'and', 'i', 'we', 'on', 'id', 'be', 'do', 'u', 'have', 'my', 'or']

# %%
def clean_string(line):
    '''
    Cleans and lemmatizes every string
    Also includes some "feature engineering"; it also includes some heuristics for dealing with compound words
    '''
    line = line.replace('\'', ' ').replace('\n', '').replace('\r', '').replace(',', '').replace('?', '').replace('.', '').strip().lower()
    words = line.split()
    new_words = []
    
    for w in words:
        #some heuristic; breakfast also appears as break fast
        #add all the tokens to the vocabulary
        if w == 'breakfast':
            w = ['break', 'fast', 'breakfast']
            for i in w:
                new_words.append(lmtzr.lemmatize(i, 'v'))
        elif w == 'bookable':
            new_words.append('book')
        elif '-' in w:
            w_copy = w
            new_w = w_copy.replace('-', '')
            w = w.replace('-', ' ') + ' ' + new_w
            for i in w.split():
                new_words.append(lmtzr.lemmatize(i, 'v'))
        else:
            new_words.append(lmtzr.lemmatize(w, 'v'))
    return (' '.join(new_words)).encode('utf-8')

# %%
def read_files(filepath, questions, answers):
    '''
    Reads in a file, parses it and returns a question, answers tuple
    '''
    i = 1
    with codecs.open('{0}'.format(filepath), encoding='utf-8', errors='ignore') as dataset:
        for line in dataset:
            if len(line) > 1:
                if i%2 == 0:
                    answers.append(clean_string(line))
                else:
                    questions.append(clean_string(line))
            i += 1
    return questions, answers

# %%
training_data_questions = []
training_data_answers = []
test_data_questions = []
test_data_answers = []

training_data_questions, training_data_answers = read_files('training_dataset.txt', training_data_questions, training_data_answers)
training_data_questions, training_data_answers = read_files('training_dataset_2.txt', training_data_questions, training_data_answers)

test_data_questions, test_data_answers = read_files('test_dataset.txt', test_data_questions, test_data_answers)
test_data_questions, test_data_answers = read_files('test-data.txt', test_data_questions, test_data_answers)

# %%
vectorizer = TfidfVectorizer(sublinear_tf=True, stop_words=stopwords + list(string.punctuation))

# %%
#Learns vocabulary from training set
vectorizer = vectorizer.fit(np.append(training_data_questions, training_data_answers))

# %%
# for i, question in enumerate(training_data_questions):
#     question_transform = vectorizer.transform([question])
#     available_answers_transform = vectorizer.transform(training_data_answers)
    
#     result = np.dot(available_answers_transform, question_transform.T).todense()
    
#     result = np.asarray(result).flatten()
#     # Sort by top results and return the indices in descending order
#     possible_answers = np.argsort(result, axis=0)[::-1]
#     print 'Question: ', question
#     print 
#     print 'Answer: ', training_data_answers[i]
#     print
#     print 'Predicted answer: ', training_data_answers[possible_answers[0]]
#     print

# %%
#Converts training features and test features into a dense document-term matrix
features = vectorizer.transform(training_data_questions).todense()
test_features = vectorizer.transform(test_data_questions).todense()

# %%
clf = RandomForestClassifier(n_estimators=2000, n_jobs=-1, max_features=1., random_state=0)
# clf = GradientBoostingClassifier(n_estimators=3000, learning_rate=0.01, random_state=0)
# clf = LogisticRegression(random_state=0)
clf.fit(features, range(0, len(training_data_answers)))
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=1.0, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=2000, n_jobs=-1, oob_score=False, random_state=0,
#             verbose=0, warm_start=False)

# %%
test_predictions = clf.predict(test_features)
print test_predictions
# Out:
# [ 2  3  4  5  5  6  7  8  9 10  0  1 11 12 13 13 14 15 16 17 18 18 20 21 22
#  23 24 25 26 27 28 28 29 30 37 24 31 31 31 32 32 32 32 33 33 33 34 34 34 35
#  35 35 35 35 36  9 36 36 37 37 37 38 38 38 39 39 39 39 40 40 40 41 41 41 42
#  42 43 43 43 44 44 45 45 45 46 37 46 47 47 48 48 49 49 49 50 50 50 51 51 51
#  52  5 52 53 53 54 54 54 55 55 58 58 59 59 60 60 61 61 62 62 63 63 64 64 64
#  65 65 66 66 63 63]

# %%
#Print question, answer and predicted answer and store wrong answers
wrong_answers = []
for i, prediction in enumerate(test_predictions):
    print 'Question: ', test_data_questions[i]
    print 
    print 'Answer: ', test_data_answers[i]
    print
    print 'Predicted answer: ', training_data_answers[prediction]
    print 
    
    if training_data_answers[prediction] != test_data_answers[i]:
        wrong_answers.append((test_data_questions[i], test_data_answers[i], training_data_answers[prediction]))
# Out:
# Question:  hey
#
# Answer:  hi
#
# Predicted answer:  hi
#
# Question:  what s up
#
# Answer:  nothing much
#
# Predicted answer:  nothing much
#
# Question:  greet
#
# Answer:  greet
#
# Predicted answer:  greet
#
# Question:  how be you
#
# Answer:  i m do good
#
# Predicted answer:  i m do good
#
# Question:  how be you do today
#
# Answer:  i m do good
#
# Predicted answer:  i m do good
#
# Question:  what s your name
#
# Answer:  i m nameless
#
# Predicted answer:  i m nameless
#
# Question:  what can you do
#
# Answer:  anything that you want
#
# Predicted answer:  anything that you want
#
# Question:  when may i check in
#
# Answer:  the date specify on your reservation
#
# Predicted answer:  the date specify on your reservation
#
# Question:  when will i be able to i check out
#
# Answer:  whenever you want to
#
# Predicted answer:  whenever you want to
#
# Question:  who be you
#
# Answer:  i be your little assistant
#
# Predicted answer:  i be your little assistant
#
# Question:  hi
#
# Answer:  hi
#
# Predicted answer:  hi
#
# Question:  hello
#
# Answer:  hi
#
# Predicted answer:  hi
#
# Question:  what s your address
#
# Answer:  i don t have an address
#
# Predicted answer:  i don t have an address
#
# Question:  what s your phone number
#
# Answer:  i don t have phone number either
#
# Predicted answer:  i don t have phone number either
#
# Question:  how can i call you
#
# Answer:  you can t call me you can only talk to me here
#
# Predicted answer:  you can t call me you can only talk to me here
#
# Question:  how can i contact you
#
# Answer:  you can t call me you can only talk to me here
#
# Predicted answer:  you can t call me you can only talk to me here
#
# Question:  can you call someone for me
#
# Answer:  sure what be their phone number
#
# Predicted answer:  sure what be their phone number
#
# Question:  can i talk to someone
#
# Answer:  sure i m get you someone to talk with you
#
# Predicted answer:  sure i m get you someone to talk with you
#
# Question:  how to get to your office
#
# Answer:  take the metro and stop at the terminus we be 5mins away from there
#
# Predicted answer:  take the metro and stop at the terminus we be 5mins away from there
#
# Question:  how to get to your office if i come from bordeaux
#
# Answer:  you need to take the tgv then at paris train station you take the subway
#
# Predicted answer:  you need to take the tgv then at paris train station you take the subway
#
# Question:  how to get to your office if i come from lyon
#
# Answer:  you need to take the tgv then at paris train station you take the subway
#
# Predicted answer:  you need to take the tgv then at paris train station you take the subway
#
# Question:  how to come to your locals if i come from brazil
#
# Answer:  none
#
# Predicted answer:  you need to take the tgv then at paris train station you take the subway
#
# Question:  how to get there from switzerland
#
# Answer:  you need to take the tgv then at paris train station you take the subway
#
# Predicted answer:  you need to take the tgv then at paris train station you take the subway
#
# Question:  how to go to your office by car
#
# Answer:  you need to take the periph and drive for 30mins
#
# Predicted answer:  you need to take the periph and drive for 30mins
#
# Question:  how to come to your office rid bike
#
# Answer:  you need to take the periph and drive for 80mins
#
# Predicted answer:  you need to take the periph and drive for 80mins
#
# Question:  how to get to your office if i come by motobike
#
# Answer:  you need to take the periph and drive for 40mins
#
# Predicted answer:  you need to take the periph and drive for 40mins
#
# Question:  i need to make an appointment
#
# Answer:  sure about what
#
# Predicted answer:  sure about what
#
# Question:  i need to see the doctor
#
# Answer:  sure about what
#
# Predicted answer:  sure about what
#
# Question:  when can the doctor be free
#
# Answer:  well depend on how urgent you need him
#
# Predicted answer:  well depend on how urgent you need him
#
# Question:  i need a new prescription
#
# Answer:  can you come to the clinic
#
# Predicted answer:  can you come to the clinic
#
# Question:  i need to make an appointment for my husband
#
# Answer:  sure for what
#
# Predicted answer:  sure for what
#
# Question:  my husband need to make an appointment
#
# Answer:  sure for what
#
# Predicted answer:  sure for what
#
# Question:  my child need a check up checkup
#
# Answer:  well please fill the form below
#
# Predicted answer:  well please fill the form below
#
# Question:  how can we book a room
#
# Answer:  hello you can book online on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book online on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to book a room
#
# Answer:  hello you can book online on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i need to book a room
#
# Answer:  hello you can book online on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  sure about what
#
# Question:  what be the best price guarantee
#
# Answer:  hello we guarantee that the price offer on our website will be the best available anywhere if not we will do more than match the competition should you find a lower rate for one of our hotels anywhere online let us know if we can be of any other help best wishesafter book with us we will match it and give you a further 25% discount do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we guarantee that the price offer on our website will be the best available anywhere if not we will do more than match the competition should you find a lower rate for one of our hotels anywhere online let us know if we can be of any other help best wishesafter book with us we will match it and give you a further 25% discount do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what be your best price guarantee
#
# Answer:  hello we guarantee that the price offer on our website will be the best available anywhere if not we will do more than match the competition should you find a lower rate for one of our hotels anywhere online let us know if we can be of any other help best wishesafter book with us we will match it and give you a further 25% discount do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we guarantee that the price offer on our website will be the best available anywhere if not we will do more than match the competition should you find a lower rate for one of our hotels anywhere online let us know if we can be of any other help best wishesafter book with us we will match it and give you a further 25% discount do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what s the best price guarantee
#
# Answer:  hello we guarantee that the price offer on our website will be the best available anywhere if not we will do more than match the competition should you find a lower rate for one of our hotels anywhere online let us know if we can be of any other help best wishesafter book with us we will match it and give you a further 25% discount do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we guarantee that the price offer on our website will be the best available anywhere if not we will do more than match the competition should you find a lower rate for one of our hotels anywhere online let us know if we can be of any other help best wishesafter book with us we will match it and give you a further 25% discount do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what be the daily rate
#
# Answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what be your daily rate
#
# Answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Question:  tell me the daily rate
#
# Answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how can i check your daily rate
#
# Answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how can i subscribe for the newsletter
#
# Answer:  hello you can subsribe to our newsletter by fill the form available at the bottom of hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can subsribe to our newsletter by fill the form available at the bottom of hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to subscribe for newsletter
#
# Answer:  hello you can subsribe to our newsletter by fill the form available at the bottom of hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can subsribe to our newsletter by fill the form available at the bottom of hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be there a way to subscribe to newsletter
#
# Answer:  hello you can subsribe to our newsletter by fill the form available at the bottom of hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can subsribe to our newsletter by fill the form available at the bottom of hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how can i unsubscribe for the newsletter
#
# Answer:  hello you can unsubscribe from our newsletter by clincking on unssubscribe next time you receive an email from us do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can unsubscribe from our newsletter by clincking on unssubscribe next time you receive an email from us do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to unsubscribe from your newsletter
#
# Answer:  hello you can unsubscribe from our newsletter by clincking on unssubscribe next time you receive an email from us do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can unsubscribe from our newsletter by clincking on unssubscribe next time you receive an email from us do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how can i unsubscribe from newsletter
#
# Answer:  hello you can unsubscribe from our newsletter by clincking on unssubscribe next time you receive an email from us do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can unsubscribe from our newsletter by clincking on unssubscribe next time you receive an email from us do not hesitate to let us know if we can be of any other help best wish
#
# Question:  at what time be check in checkin
#
# Answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what time be your checkin
#
# Answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what be your checkin time
#
# Answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what time can i checkin
#
# Answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  when can i checkin
#
# Answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  at what time be check out checkout
#
# Answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello check out checkout be at 1200pm should you wish to leave the hotel later we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  when can i check out
#
# Answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  whenever you want to
#
# Question:  what time be checkout
#
# Answer:  hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello check out checkout be at 1200pm should you wish to leave the hotel later we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to checkout
#
# Answer:  hello check out checkout be at 1200pm should you wish to leave the hotel later we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello check out checkout be at 1200pm should you wish to leave the hotel later we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  do you offer handicap room
#
# Answer:  hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i get handicap room
#
# Answer:  hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish
#
# Question:  do u offer handicap room
#
# Answer:  hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be park available at the hotel
#
# Answer:  hello we offer complimentary valet park for our hotel and restaurant guests do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we offer complimentary valet park for our hotel and restaurant guests do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be there park available at the hotel
#
# Answer:  hello we offer complimentary valet park for our hotel and restaurant guests do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we offer complimentary valet park for our hotel and restaurant guests do not hesitate to let us know if we can be of any other help best wish
#
# Question:  do you have park space in the hotel
#
# Answer:  hello we offer complimentary valet park for our hotel and restaurant guests do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we offer complimentary valet park for our hotel and restaurant guests do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i reserve a park lot
#
# Answer:  hello you cannot book a park lot but we offer complimentary valet park to all guests do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you cannot book a park lot but we offer complimentary valet park to all guests do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i reserve for park lot
#
# Answer:  hello you cannot book a park lot but we offer complimentary valet park to all guests do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you cannot book a park lot but we offer complimentary valet park to all guests do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i reserve for park space
#
# Answer:  hello you cannot book a park lot but we offer complimentary valet park to all guests do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you cannot book a park lot but we offer complimentary valet park to all guests do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to reserve for park space
#
# Answer:  hello you cannot book a park lot but we offer complimentary valet park to all guests do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you cannot book a park lot but we offer complimentary valet park to all guests do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what be the reception open hours
#
# Answer:  hello the reception be open 24 hours a day do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello the reception be open 24 hours a day do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what be your reception open hours
#
# Answer:  hello the reception be open 24 hours a day do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello the reception be open 24 hours a day do not hesitate to let us know if we can be of any other help best wish
#
# Question:  tell me your open hours
#
# Answer:  hello the reception be open 24 hours a day do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello the reception be open 24 hours a day do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i also book break fast breakfast online what do it cost
#
# Answer:  hello you can book your break fast breakfast online at time of book or on arrival during your check in checkin the price of our buffet break fast breakfast at 3in1 be aed 125 do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book your break fast breakfast online at time of book or on arrival during your check in checkin the price of our buffet break fast breakfast at 3in1 be aed 125 do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what be the cost of book break fast breakfast online
#
# Answer:  hello you can book your break fast breakfast online at time of book or on arrival during your check in checkin the price of our buffet break fast breakfast at 3in1 be aed 125 do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book your break fast breakfast online at time of book or on arrival during your check in checkin the price of our buffet break fast breakfast at 3in1 be aed 125 do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i book break fast online
#
# Answer:  hello you can book your break fast breakfast online at time of book or on arrival during your check in checkin the price of our buffet break fast breakfast at 3in1 be aed 125 do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book your break fast breakfast online at time of book or on arrival during your check in checkin the price of our buffet break fast breakfast at 3in1 be aed 125 do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be half or full board available
#
# Answer:  hello half and full board be available upon request at time of reservation do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello half and full board be available upon request at time of reservation do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be half full board available
#
# Answer:  hello half and full board be available upon request at time of reservation do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello half and full board be available upon request at time of reservation do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be it possible to book spa treatments online
#
# Answer:  hello our hotel do not have its own spa area however we offer discount vouchers to the spa at the palace downtown dubai which be just across the boulevard do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello our hotel do not have its own spa area however we offer discount vouchers to the spa at the palace downtown dubai which be just across the boulevard do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i book spa treatments online
#
# Answer:  hello our hotel do not have its own spa area however we offer discount vouchers to the spa at the palace downtown dubai which be just across the boulevard do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello our hotel do not have its own spa area however we offer discount vouchers to the spa at the palace downtown dubai which be just across the boulevard do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to book a spa treatments
#
# Answer:  hello our hotel do not have its own spa area however we offer discount vouchers to the spa at the palace downtown dubai which be just across the boulevard do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello our hotel do not have its own spa area however we offer discount vouchers to the spa at the palace downtown dubai which be just across the boulevard do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i book tee time online
#
# Answer:  i want to book tee time
#
# Predicted answer:  hello reservations for any of our restaurants can be make on our website hyphenai on our mobile app by phone 555 800 4567 or email help@hyphenai do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  be it possible to book tee time online
#
# Answer:  hello reservations for any of our restaurants can be make on our website hyphenai on our mobile app by phone 555 800 4567 or email help@hyphenai do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello reservations for any of our restaurants can be make on our website hyphenai on our mobile app by phone 555 800 4567 or email help@hyphenai do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  can i bring my pet
#
# Answer:  hello unfortunately our hotel do not accommodate pet do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello unfortunately our hotel do not accommodate pet do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to bring my pet to hotel
#
# Answer:  hello unfortunately our hotel do not accommodate pet do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello unfortunately our hotel do not accommodate pet do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be it allow to bring my pet to hotel
#
# Answer:  hello unfortunately our hotel do not accommodate pet do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello unfortunately our hotel do not accommodate pet do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how much do it cost a room per night
#
# Answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Question:  what be the cost of your room
#
# Answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish
#
# Question:  where can i see your hotel rat
#
# Answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be the rat per person or per room
#
# Answer:  hello the rat be automatically calculate per room per night however you need to specify if your request be for a single or a double occupancy do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello the rat be automatically calculate per room per night however you need to specify if your request be for a single or a double occupancy do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  be your hotel rat per person or per room
#
# Answer:  hello the rat be automatically calculate per room per night however you need to specify if your request be for a single or a double occupancy do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello the rat be automatically calculate per room per night however you need to specify if your request be for a single or a double occupancy do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  why do the cost vary from day to day
#
# Answer:  hello the rat vary depend on the season do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello the rat vary depend on the season do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  why be your cost vary from day to day
#
# Answer:  hello the rat vary depend on the season do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello the rat vary depend on the season do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  can i book two room of different categories
#
# Answer:  hello you can book two room of two different categories to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book two room of two different categories to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can we book two room for different categories
#
# Answer:  hello you can book two room of two different categories to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book two room of two different categories to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be it possible to book two room for diffeerent categories
#
# Answer:  hello you can book two room of two different categories to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book two room of two different categories to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i book two room with different occupancy
#
# Answer:  hello you can book two room with different occupancy to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book two room with different occupancy to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can we book two room for different occupancy
#
# Answer:  hello you can book two room with different occupancy to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book two room with different occupancy to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be it possible to book two room for diffeerent occupancy
#
# Answer:  hello you can book two room with different occupancy to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can book two room with different occupancy to do so you can visit hyphenai our mobile app give us a call on 555 800 4567 or email us on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be wi fi wifi available at the hotel/in the room
#
# Answer:  hello we offer complimentary high speed wi fi wifi to all of our guests in addition a premium offer be also available at an additional fee do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we offer complimentary high speed wi fi wifi to all of our guests in addition a premium offer be also available at an additional fee do not hesitate to let us know if we can be of any other help best wish
#
# Question:  do you have wifi available in hotel room
#
# Answer:  hello we offer complimentary high speed wi fi wifi to all of our guests in addition a premium offer be also available at an additional fee do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we offer complimentary high speed wi fi wifi to all of our guests in addition a premium offer be also available at an additional fee do not hesitate to let us know if we can be of any other help best wish
#
# Question:  do u have wifi in the room
#
# Answer:  hello we offer complimentary high speed wi fi wifi to all of our guests in addition a premium offer be also available at an additional fee do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we offer complimentary high speed wi fi wifi to all of our guests in addition a premium offer be also available at an additional fee do not hesitate to let us know if we can be of any other help best wish
#
# Question:  which size be the room
#
# Answer:  hello we have room in four different categories and their size vary from 32m to 140m do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we have room in four different categories and their size vary from 32m to 140m do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how big be the room
#
# Answer:  hello we have room in four different categories and their size vary from 32m to 140m do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  i m do good
#
# Question:  what be the size of the room
#
# Answer:  hello we have room in four different categories and their size vary from 32m to 140m do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we have room in four different categories and their size vary from 32m to 140m do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i reserve a table in a restaurant
#
# Answer:  hello reservations for any of our restaurants can be make on our website hyphenai on our mobile app by phone 555 800 4567 or email help@hyphenai do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello reservations for any of our restaurants can be make on our website hyphenai on our mobile app by phone 555 800 4567 or email help@hyphenai do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  can i reserve a table in your restaurant
#
# Answer:  hello reservations for any of our restaurants can be make on our website hyphenai on our mobile app by phone 555 800 4567 or email help@hyphenai do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello reservations for any of our restaurants can be make on our website hyphenai on our mobile app by phone 555 800 4567 or email help@hyphenai do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  do you offer non smoke nonsmoking room
#
# Answer:  hello all of our room be non smoke nonsmoking however you can smoke in the designate areas best wish
#
# Predicted answer:  hello all of our room be non smoke nonsmoking however you can smoke in the designate areas best wish
#
# Question:  be there non smoke room
#
# Answer:  hello all of our room be non smoke nonsmoking however you can smoke in the designate areas best wish
#
# Predicted answer:  hello all of our room be non smoke nonsmoking however you can smoke in the designate areas best wish
#
# Question:  do u have non smoke nonsmoking room
#
# Answer:  hello all of our room be non smoke nonsmoking however you can smoke in the designate areas best wish
#
# Predicted answer:  hello all of our room be non smoke nonsmoking however you can smoke in the designate areas best wish
#
# Question:  do you offer child rat
#
# Answer:  hello 3in1 offer meals adapt to kid do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello 3in1 offer meals adapt to kid do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  can we get offer for child rat
#
# Answer:  hello 3in1 offer meals adapt to kid do not hesitate to let us know if we can be of any other assistance best wish
#
# Predicted answer:  hello 3in1 offer meals adapt to kid do not hesitate to let us know if we can be of any other assistance best wish
#
# Question:  how do i know if the hotel be book
#
# Answer:  hello you can check the availability of the hotel on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can check the availability of the hotel on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how can i know if hotel room be book
#
# Answer:  hello you can check the availability of the hotel on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can check the availability of the hotel on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be special request such as gluten free glutenfree meals or feather free featherfree pillow manageable
#
# Answer:  hello we do offer gluten free glutenfree meals and feather free featherfree pillow we do our very best to fulfil all the special request do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we do offer gluten free glutenfree meals and feather free featherfree pillow we do our very best to fulfil all the special request do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be there special request such as gluten free meals
#
# Answer:  hello we do offer gluten free glutenfree meals and feather free featherfree pillow we do our very best to fulfil all the special request do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we do offer gluten free glutenfree meals and feather free featherfree pillow we do our very best to fulfil all the special request do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how many room can be book at once
#
# Answer:  hello you be most welcome to book as many room as our availability offer do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you be most welcome to book as many room as our availability offer do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how many room can i book at once
#
# Answer:  hello you be most welcome to book as many room as our availability offer do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you be most welcome to book as many room as our availability offer do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i book without credit card
#
# Answer:  hello you can only book without credit card as walkin and by provide advance payment cash do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can only book without credit card as walkin and by provide advance payment cash do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i book your hotel without credit card
#
# Answer:  hello you can only book without credit card as walkin and by provide advance payment cash do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you can only book without credit card as walkin and by provide advance payment cash do not hesitate to let us know if we can be of any other help best wish
#
# Question:  which online payment methods do you offer
#
# Answer:  hello we offer visa and mastercard online payment methods do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we offer visa and mastercard online payment methods do not hesitate to let us know if we can be of any other help best wish
#
# Question:  which online payment methods do u accept
#
# Answer:  hello we offer visa and mastercard online payment methods do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello we offer visa and mastercard online payment methods do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be my credit card be charge at time of book
#
# Answer:  hello when book directly from our websites the credit card be only use to guarantee the book the full payment will be process at time of check out checkout do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello when book directly from our websites the credit card be only use to guarantee the book the full payment will be process at time of check out checkout do not hesitate to let us know if we can be of any other help best wish
#
# Question:  do you charge my card at time of book
#
# Answer:  hello when book directly from our websites the credit card be only use to guarantee the book the full payment will be process at time of check out checkout do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello when book directly from our websites the credit card be only use to guarantee the book the full payment will be process at time of check out checkout do not hesitate to let us know if we can be of any other help best wish
#
# Question:  how can i change or cancel my reservation
#
# Answer:  hello if you would like to change your reservation the best wau be to contact us directly by phone on 555 800 4567 or by email on reservations@hyphenai you can cancel your reservation untill 600pm on the date of arrival if the reservation have be make directly with us and do not include any offer do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello if you would like to change your reservation the best wau be to contact us directly by phone on 555 800 4567 or by email on reservations@hyphenai you can cancel your reservation untill 600pm on the date of arrival if the reservation have be make directly with us and do not include any offer do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to cancel my reservation
#
# Answer:  hello if you would like to change your reservation the best wau be to contact us directly by phone on 555 800 4567 or by email on reservations@hyphenai you can cancel your reservation untill 600pm on the date of arrival if the reservation have be make directly with us and do not include any offer do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello if you would like to change your reservation the best wau be to contact us directly by phone on 555 800 4567 or by email on reservations@hyphenai you can cancel your reservation untill 600pm on the date of arrival if the reservation have be make directly with us and do not include any offer do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to change my reservation
#
# Answer:  hello if you would like to change your reservation the best wau be to contact us directly by phone on 555 800 4567 or by email on reservations@hyphenai you can cancel your reservation untill 600pm on the date of arrival if the reservation have be make directly with us and do not include any offer do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello if you would like to change your reservation the best wau be to contact us directly by phone on 555 800 4567 or by email on reservations@hyphenai you can cancel your reservation untill 600pm on the date of arrival if the reservation have be make directly with us and do not include any offer do not hesitate to let us know if we can be of any other help best wish
#
# Question:  by when do i have to cancel my book if i have to
#
# Answer:  hello your reservation can be cancel before 600 pm on the arrival date if you book directly with us and do not use any special offer do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello your reservation can be cancel before 600 pm on the arrival date if you book directly with us and do not use any special offer do not hesitate to let us know if we can be of any other help best wish
#
# Question:  i want to cancel my book when can i do that
#
# Answer:  hello your reservation can be cancel before 600 pm on the arrival date if you book directly with us and do not use any special offer do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello your reservation can be cancel before 600 pm on the arrival date if you book directly with us and do not use any special offer do not hesitate to let us know if we can be of any other help best wish
#
# Question:  can i check in checkin without my reservation number
#
# Answer:  hello you be welcome to check in checkin without the reservation number but we do require a valid passport or emirates id from every guest stay with us do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you be welcome to check in checkin without the reservation number but we do require a valid passport or emirates id from every guest stay with us do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be it possible to check in without my reservation number
#
# Answer:  hello you be welcome to check in checkin without the reservation number but we do require a valid passport or emirates id from every guest stay with us do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello you be welcome to check in checkin without the reservation number but we do require a valid passport or emirates id from every guest stay with us do not hesitate to let us know if we can be of any other help best wish
#
# Question:  do you charge my card at time of book
#
# Answer:  hello when book directly from our websites the credit card be only use to guarantee the book the full payment will be process at time of check out checkout do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello when book directly from our websites the credit card be only use to guarantee the book the full payment will be process at time of check out checkout do not hesitate to let us know if we can be of any other help best wish
#
# Question:  be my credit card be charge at time of book
#
# Answer:  hello when book directly from our websites the credit card be only use to guarantee the book the full payment will be process at time of check out checkout do not hesitate to let us know if we can be of any other help best wish
#
# Predicted answer:  hello when book directly from our websites the credit card be only use to guarantee the book the full payment will be process at time of check out checkout do not hesitate to let us know if we can be of any other help best wish

# %%
#calculate error rate
print 'Error rate:', (len(wrong_answers) * 1.0 /len(test_data_questions)) * 100, '%'
# Out:
# Error rate: 6.87022900763 %

# %%
wrong_answers
# Out:
# [('how to come to your locals if i come from brazil',
#   'none',
#   'you need to take the tgv then at paris train station you take the subway'),
#  ('i want to book a room',
#   'hello you can book online on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish',
#   'hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish'),
#  ('i need to book a room',
#   'hello you can book online on hyphenai on our mobile app by give us a call on 555 800 4567 or by email on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish',
#   'sure about what'),
#  ('at what time be check out checkout',
#   'hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish',
#   'hello check out checkout be at 1200pm should you wish to leave the hotel later we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish'),
#  ('when can i check out',
#   'hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish',
#   'whenever you want to'),
#  ('what time be checkout',
#   'hello check in checkin be at 300pm should you wish to arrive earlier we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish',
#   'hello check out checkout be at 1200pm should you wish to leave the hotel later we advise you to get in touch with our reservations team on reservations@hyphenai do not hesitate to let us know if we can be of any other help best wish'),
#  ('can i book tee time online',
#   'i want to book tee time',
#   'hello reservations for any of our restaurants can be make on our website hyphenai on our mobile app by phone 555 800 4567 or email help@hyphenai do not hesitate to let us know if we can be of any other assistance best wish'),
#  ('what be the cost of your room',
#   'hello you can check our rat anytime of the day on hyphenai or on our mobile app do not hesitate to let us know if we can be of any other help best wish',
#   'hello physically challenge room be also available and the hotel have be design to make all guests feel comfortable do not hesitate to let us know if we can be of any other help best wish'),
#  ('how big be the room',
#   'hello we have room in four different categories and their size vary from 32m to 140m do not hesitate to let us know if we can be of any other help best wish',
#   'i m do good')]

# %%
len(wrong_answers)
# Out:
# 9

# %%
vectorizer.vocabulary_
# Out:
# {u'1200pm': 0,
#  u'125': 1,
#  u'140m': 2,
#  u'24': 3,
#  u'25': 4,
#  u'300pm': 5,
#  u'30mins': 6,
#  u'32m': 7,
#  u'3in1': 8,
#  u'40mins': 9,
#  u'4567': 10,
#  u'555': 11,
#  u'5mins': 12,
#  u'600': 13,
#  u'600pm': 14,
#  u'800': 15,
#  u'80mins': 16,
#  u'about': 17,
#  u'accommodate': 18,
#  u'across': 19,
#  u'adapt': 20,
#  u'addition': 21,
#  u'additional': 22,
#  u'address': 23,
#  u'advance': 24,
#  u'advise': 25,
#  u'aed': 26,
#  u'after': 27,
#  u'all': 28,
#  u'also': 29,
#  u'any': 30,
#  u'anything': 31,
#  u'anytime': 32,
#  u'anywhere': 33,
#  u'app': 34,
#  u'appointment': 35,
#  u'area': 36,
#  u'areas': 37,
#  u'arrival': 38,
#  u'arrive': 39,
#  u'as': 40,
#  u'assistance': 41,
#  u'assistant': 42,
#  u'automatically': 43,
#  u'availability': 44,
#  u'available': 45,
#  u'away': 46,
#  u'before': 47,
#  u'below': 48,
#  u'best': 49,
#  u'bike': 50,
#  u'board': 51,
#  u'book': 52,
#  u'bordeaux': 53,
#  u'bottom': 54,
#  u'boulevard': 55,
#  u'break': 56,
#  u'breakfast': 57,
#  u'bring': 58,
#  u'buffet': 59,
#  u'but': 60,
#  u'by': 61,
#  u'calculate': 62,
#  u'call': 63,
#  u'can': 64,
#  u'cancel': 65,
#  u'cannot': 66,
#  u'car': 67,
#  u'card': 68,
#  u'cash': 69,
#  u'categories': 70,
#  u'challenge': 71,
#  u'change': 72,
#  u'charge': 73,
#  u'check': 74,
#  u'checkin': 75,
#  u'checkout': 76,
#  u'checkup': 77,
#  u'child': 78,
#  u'clincking': 79,
#  u'clinic': 80,
#  u'come': 81,
#  u'comfortable': 82,
#  u'competition': 83,
#  u'complimentary': 84,
#  u'contact': 85,
#  u'cost': 86,
#  u'credit': 87,
#  u'daily': 88,
#  u'date': 89,
#  u'day': 90,
#  u'depend': 91,
#  u'design': 92,
#  u'designate': 93,
#  u'different': 94,
#  u'directly': 95,
#  u'discount': 96,
#  u'doctor': 97,
#  u'don': 98,
#  u'double': 99,
#  u'downtown': 100,
#  u'drive': 101,
#  u'dubai': 102,
#  u'during': 103,
#  u'earlier': 104,
#  u'either': 105,
#  u'email': 106,
#  u'emirates': 107,
#  u'even': 108,
#  u'every': 109,
#  u'fast': 110,
#  u'feather': 111,
#  u'featherfree': 112,
#  u'fee': 113,
#  u'feel': 114,
#  u'fi': 115,
#  u'fill': 116,
#  u'find': 117,
#  u'for': 118,
#  u'form': 119,
#  u'four': 120,
#  u'free': 121,
#  u'from': 122,
#  u'fulfil': 123,
#  u'full': 124,
#  u'further': 125,
#  u'get': 126,
#  u'give': 127,
#  u'gluten': 128,
#  u'glutenfree': 129,
#  u'good': 130,
#  u'greet': 131,
#  u'guarantee': 132,
#  u'guest': 133,
#  u'guests': 134,
#  u'half': 135,
#  u'handicap': 136,
#  u'hello': 137,
#  u'help': 138,
#  u'here': 139,
#  u'hesitate': 140,
#  u'hey': 141,
#  u'hi': 142,
#  u'high': 143,
#  u'him': 144,
#  u'hotel': 145,
#  u'hotels': 146,
#  u'hours': 147,
#  u'how': 148,
#  u'however': 149,
#  u'husband': 150,
#  u'hyphenai': 151,
#  u'include': 152,
#  u'its': 153,
#  u'just': 154,
#  u'kid': 155,
#  u'know': 156,
#  u'later': 157,
#  u'leave': 158,
#  u'let': 159,
#  u'like': 160,
#  u'little': 161,
#  u'lot': 162,
#  u'lower': 163,
#  u'lyon': 164,
#  u'make': 165,
#  u'manageable': 166,
#  u'many': 167,
#  u'marseille': 168,
#  u'mastercard': 169,
#  u'match': 170,
#  u'me': 171,
#  u'meals': 172,
#  u'methods': 173,
#  u'metro': 174,
#  u'mobile': 175,
#  u'more': 176,
#  u'most': 177,
#  u'motobike': 178,
#  u'much': 179,
#  u'name': 180,
#  u'nameless': 181,
#  u'need': 182,
#  u'newsletter': 183,
#  u'next': 184,
#  u'night': 185,
#  u'non': 186,
#  u'nonsmoking': 187,
#  u'not': 188,
#  u'nothing': 189,
#  u'number': 190,
#  u'occupancy': 191,
#  u'offer': 192,
#  u'office': 193,
#  u'once': 194,
#  u'one': 195,
#  u'online': 196,
#  u'only': 197,
#  u'open': 198,
#  u'other': 199,
#  u'our': 200,
#  u'out': 201,
#  u'own': 202,
#  u'palace': 203,
#  u'paris': 204,
#  u'park': 205,
#  u'passport': 206,
#  u'payment': 207,
#  u'per': 208,
#  u'periph': 209,
#  u'person': 210,
#  u'pet': 211,
#  u'phone': 212,
#  u'physically': 213,
#  u'pillow': 214,
#  u'please': 215,
#  u'pm': 216,
#  u'possible': 217,
#  u'premium': 218,
#  u'prescription': 219,
#  u'price': 220,
#  u'process': 221,
#  u'provide': 222,
#  u'rat': 223,
#  u'rate': 224,
#  u'rates': 225,
#  u'receive': 226,
#  u'reception': 227,
#  u'renew': 228,
#  u'request': 229,
#  u'require': 230,
#  u'reservation': 231,
#  u'reservations': 232,
#  u'reserve': 233,
#  u'restaurant': 234,
#  u'restaurants': 235,
#  u'room': 236,
#  u'season': 237,
#  u'see': 238,
#  u'should': 239,
#  u'single': 240,
#  u'size': 241,
#  u'smoke': 242,
#  u'so': 243,
#  u'someone': 244,
#  u'spa': 245,
#  u'special': 246,
#  u'specify': 247,
#  u'speed': 248,
#  u'station': 249,
#  u'stay': 250,
#  u'stop': 251,
#  u'subscribe': 252,
#  u'subsribe': 253,
#  u'subway': 254,
#  u'such': 255,
#  u'sure': 256,
#  u'switzerland': 257,
#  u'table': 258,
#  u'take': 259,
#  u'talk': 260,
#  u'team': 261,
#  u'tee': 262,
#  u'terminus': 263,
#  u'tgv': 264,
#  u'than': 265,
#  u'that': 266,
#  u'their': 267,
#  u'then': 268,
#  u'there': 269,
#  u'time': 270,
#  u'touch': 271,
#  u'train': 272,
#  u'treatments': 273,
#  u'two': 274,
#  u'unfortunately': 275,
#  u'unssubscribe': 276,
#  u'unsubscribe': 277,
#  u'untill': 278,
#  u'up': 279,
#  u'upon': 280,
#  u'urgent': 281,
#  u'us': 282,
#  u'use': 283,
#  u'valet': 284,
#  u'valid': 285,
#  u'vary': 286,
#  u'very': 287,
#  u'visa': 288,
#  u'visit': 289,
#  u'vouchers': 290,
#  u'walkin': 291,
#  u'want': 292,
#  u'wau': 293,
#  u'website': 294,
#  u'websites': 295,
#  u'welcome': 296,
#  u'well': 297,
#  u'what': 298,
#  u'when': 299,
#  u'whenever': 300,
#  u'where': 301,
#  u'which': 302,
#  u'who': 303,
#  u'why': 304,
#  u'wi': 305,
#  u'wifi': 306,
#  u'will': 307,
#  u'wish': 308,
#  u'wishesafter': 309,
#  u'with': 310,
#  u'without': 311,
#  u'would': 312,
#  u'you': 313,
#  u'your': 314}
